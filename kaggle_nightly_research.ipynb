# %% [markdown]
# # Apex Oracle - Nightly Research Pipeline
# This notebook runs the NAS and Evolutionary PPO tournament on Kaggle GPUs.

# %%
# !git clone https://github.com/brianfreshour944-gif/Apex_oracle_bot.git
# %cd Apex_oracle_bot
# !pip install polars yfinance scikit-learn stable-baselines3

# %%
# Copy the uploaded live experiences dataset into the data directory
# !mkdir -p data
# !cp ../input/apex-oracle-live-data/live_experiences.jsonl data/live_experiences.jsonl || echo 'No live data found, proceeding with historical only.'

# %%
# Run the full nightly pipeline
# !python scripts/nightly_research_pipeline.py

# %%
# Copy models to the Kaggle working directory so they can be downloaded by the sync script
# !cp models/grok_gqa_v9_best.pth /kaggle/working/
# !cp models/ppo_meta_weights.zip /kaggle/working/
# !cp models/transformer_config.json /kaggle/working/
# !cp models/feature_scaler.pkl /kaggle/working/
